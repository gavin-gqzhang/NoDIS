# %%
from maskrcnn_benchmark.data.datasets.visual_genome import load_info, load_graphs,load_image_filenames
from maskrcnn_benchmark.structures.bounding_box import BoxList
import numpy as np
from PIL import Image
import random
import torch
import cv2
from collections import defaultdict

BOX_SCALE = 1024

# %%
base_path="/data/sdc/SGG_data/"

dict_file=base_path+"VG/VG-SGG-dicts-with-attri.json"
roidb_file=base_path+"VG/VG-SGG-with-attri.h5"
image_file=base_path+"VG/image_data.json"
image_dir=base_path+"VG/VG_100K"

# %%
ind_to_classes,ind_to_predicates,ind_to_attributes=load_info(dict_file)

split_mask,gt_boxes,gt_classes,gt_attributes,relationships=load_graphs(roidb_file,split='train',num_im=-1,num_val_im=5000,filter_empty_rels=False,filter_non_overlap=False)
filenames,img_info=load_image_filenames(image_dir,image_file)

filenames=[filenames[i] for i in np.where(split_mask)[0]]
img_infos=[img_info[i] for i in np.where(split_mask)[0]]

# %%
def get_groundtruth(index, evaluation=False, flip_img=False):
    img_info = img_infos[index]
    w, h = img_info['width'], img_info['height']
    # important: recover original box from BOX_SCALE
    box = gt_boxes[index] / BOX_SCALE * max(w, h)
    box = torch.from_numpy(box).reshape(-1, 4)  # guard against no boxes
    if flip_img:
        new_xmin = w - box[:,2]
        new_xmax = w - box[:,0]
        box[:,0] = new_xmin
        box[:,2] = new_xmax
    target = BoxList(box, (w, h), 'xyxy') # xyxy

    target.add_field("labels", torch.from_numpy(gt_classes[index]))
    target.add_field("attributes", torch.from_numpy(gt_attributes[index]))

    relation = relationships[index].copy() # (num_rel, 3)

    old_size = relation.shape[0]
    all_rel_sets = defaultdict(list)
    for (o0, o1, r) in relation:
        all_rel_sets[(o0, o1)].append(r)
    relation = [(k[0], k[1], np.random.choice(v)) for k,v in all_rel_sets.items()]
    relation = np.array(relation, dtype=np.int32)
    
    # add relation to target
    num_box = len(target)
    relation_map = torch.zeros((num_box, num_box), dtype=torch.int64)
    for i in range(relation.shape[0]):
        if relation_map[int(relation[i,0]), int(relation[i,1])] > 0:
            if (random.random() > 0.5):
                relation_map[int(relation[i,0]), int(relation[i,1])] = int(relation[i,2])
        else:
            relation_map[int(relation[i,0]), int(relation[i,1])] = int(relation[i,2])
    target.add_field("relation", relation_map, is_triplet=True)

    target = target.clip_to_image(remove_empty=False)
    target.add_field("relation_tuple", torch.LongTensor(relation)) # for evaluation
    return target

# %%
wo_idx=ind_to_predicates.index('walking on')

include_wo_samples,others=[],[]
for idx in range(len(filenames)):
    target=get_groundtruth(idx)
    target_rels=target.get_field('relation_tuple')
    if len(target_rels)==0:
        continue
    
    print(target_rels[:,2],wo_idx in target_rels[:,2])

    if wo_idx in target_rels[:,2]:
        include_wo_samples.append(idx)
    else:
        others.append(idx)
    
    if len(include_wo_samples)>20:
        break
# Out:
# tensor([20, 20]) False
# tensor([31, 20]) False
# tensor([49, 47, 48, 49, 49]) False
# tensor([31]) False
# tensor([20, 20, 30, 30]) False
# tensor([29, 20]) False
# tensor([48, 38, 20, 38, 50, 22, 22, 50]) False
# tensor([21, 30]) False
# tensor([20, 20, 20,  8,  8]) False
# tensor([31, 31]) False
# tensor([30, 30]) False
# tensor([48, 20,  8, 49]) False
# tensor([48, 31, 21, 31, 20, 48]) False
# tensor([31]) False
# tensor([30]) False
# tensor([31]) False
# tensor([37, 22, 47, 48]) False
# tensor([31, 31, 48, 48, 48, 20, 38, 48, 48]) False
# tensor([29, 29]) False
# tensor([31]) False
# tensor([20, 31, 31, 31, 31, 48, 48, 48, 43, 20, 31, 30, 38, 38, 48, 48]) False
# tensor([50]) False
# tensor([21,  8, 48, 48]) False
# tensor([40, 31, 20, 20, 31, 31, 49, 20, 49, 49, 20, 48, 33]) False
# tensor([23, 30]) False
# tensor([31, 31]) False
# tensor([ 9, 20, 30]) False
# tensor([48, 30, 31]) False
# tensor([31]) False
# tensor([20, 20]) False
# tensor([22, 10, 10, 22, 22, 22, 22, 31, 50, 20]) False
# tensor([50, 50]) False
# tensor([50, 31, 20,  8, 21, 48, 48, 31, 50, 50]) False
# tensor([31, 31, 31]) False
# tensor([31, 31, 31, 31, 22]) False
# tensor([20, 20, 20]) False
# tensor([8, 1]) False
# tensor([48, 48, 48, 48]) False
# tensor([22, 22, 31, 31]) False
# tensor([20, 20, 20]) False
# tensor([20]) False
# tensor([31, 16, 21]) False
# tensor([31, 20,  8, 29]) False
# tensor([31]) False
# tensor([43,  8, 30, 11]) False
# tensor([29, 22, 31]) False
# tensor([40, 30, 24]) False
# tensor([ 8,  8,  8,  8, 31, 31, 47]) False
# tensor([48, 11, 22, 22, 48]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 20]) False
# tensor([31, 20]) False
# tensor([31, 31, 31, 31, 31, 20, 31, 20, 31, 20, 20, 20, 20,  7, 31, 31]) False
# tensor([20, 31, 31, 20, 31, 29, 29, 31, 31, 29, 50]) False
# tensor([31, 31, 31, 31]) False
# tensor([31]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 30]) False
# tensor([27, 48, 48, 20]) False
# tensor([31, 31, 31, 31, 31, 31, 42]) False
# tensor([20, 20, 20, 31, 20, 31]) False
# tensor([31, 31, 31, 31, 31,  8, 31]) False
# tensor([48, 31, 31, 31, 31, 31, 22, 21, 21, 43, 22]) False
# tensor([48, 48,  8, 48, 22, 22, 22, 22, 22, 50, 31]) False
# tensor([20, 31, 40, 31,  9,  9,  9, 31]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 31]) False
# tensor([31, 31, 31, 30, 31, 31]) False
# tensor([31, 31, 31, 31, 31, 31, 31]) False
# tensor([30]) False
# tensor([22, 22, 22, 22,  8, 22]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([31, 22]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([48, 48]) False
# tensor([ 1, 14, 31, 22, 22, 29]) False
# tensor([31, 20, 50]) False
# tensor([22, 20,  8, 20]) False
# tensor([31, 31, 31, 31]) False
# tensor([31, 22]) False
# tensor([30, 21, 30, 22, 22, 22, 21, 31]) False
# tensor([31, 31, 31, 31, 31, 22, 22, 31, 31]) False
# tensor([29, 29]) False
# tensor([20, 31, 31, 31]) False
# tensor([22]) False
# tensor([31, 48, 20, 30, 30,  8]) False
# tensor([48, 20, 25]) False
# tensor([31]) False
# tensor([40]) False
# tensor([29, 22, 20]) False
# tensor([48, 31, 48, 31, 31, 20]) False
# tensor([ 8, 20]) False
# tensor([48,  8, 31, 50, 48, 30, 30, 30]) False
# tensor([30, 30, 30, 20, 20, 20, 20]) False
# tensor([31]) False
# tensor([20, 48, 30, 48,  8]) False
# tensor([29, 31]) False
# tensor([20, 20, 31, 31, 31, 31, 31]) False
# tensor([49, 20, 49, 20, 22, 20, 20, 22, 20, 20]) False
# tensor([31, 29, 29,  8, 31]) False
# tensor([50, 29]) False
# tensor([31, 31, 21, 31, 31]) False
# tensor([31, 31]) False
# tensor([48, 22, 22, 22, 20, 29, 22, 29, 31, 29,  1,  1]) False
# tensor([31, 31, 31, 50, 35,  8, 29]) False
# tensor([21, 31]) False
# tensor([31, 22, 31, 20]) False
# tensor([20, 20]) False
# tensor([31, 22, 22, 31, 31, 22, 31]) False
# tensor([31, 31, 29, 29]) False
# tensor([31, 31, 31]) False
# tensor([20]) False
# tensor([1]) False
# tensor([41, 38, 31, 31]) False
# tensor([41, 24,  6, 31, 20]) False
# tensor([49, 30]) False
# tensor([38, 29]) False
# tensor([31, 30, 30]) False
# tensor([20, 20, 20, 20, 20, 20, 20, 20, 20]) False
# tensor([48, 31, 31, 48, 48, 31, 31, 29, 29, 48, 22]) False
# tensor([22, 31,  8, 22, 23, 29, 31, 29,  8]) False
# tensor([21, 49, 20, 20]) False
# tensor([50, 50]) False
# tensor([48]) False
# tensor([31, 31, 29, 50, 31, 20, 20, 20, 20, 20, 41, 31, 31,  5, 20, 20, 20]) False
# tensor([31, 31, 31, 31]) False
# tensor([31, 31, 31, 31, 31]) False
# tensor([29, 29, 31,  8,  8]) False
# tensor([20, 20, 20, 20]) False
# tensor([30, 50, 30, 31]) False
# tensor([48, 48, 48, 48, 48]) False
# tensor([31]) False
# tensor([31]) False
# tensor([31, 48]) False
# tensor([20, 20, 31, 29]) False
# tensor([29,  7,  7]) False
# tensor([31, 31, 31]) False
# tensor([48, 13]) False
# tensor([38, 50, 48, 38]) False
# tensor([48, 48, 48]) False
# tensor([21]) False
# tensor([31, 31, 31, 31, 31]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([22, 20]) False
# tensor([29]) False
# tensor([20, 20, 20, 20, 20, 20, 20, 20, 20]) False
# tensor([21, 50, 48, 48, 48, 48, 29, 48, 48, 48]) False
# tensor([20, 31, 20, 31]) False
# tensor([48, 20, 48]) False
# tensor([29, 29]) False
# tensor([31]) False
# tensor([20, 22, 31]) False
# tensor([31, 31, 31]) False
# tensor([22, 20, 20]) False
# tensor([31, 31, 31, 31, 31, 23]) False
# tensor([30, 30, 30, 30]) False
# tensor([21, 31, 43, 50, 31, 31, 31, 22, 22, 22, 22]) False
# tensor([49, 49]) False
# tensor([29]) False
# tensor([8]) False
# tensor([20]) False
# tensor([29,  8,  8,  8]) False
# tensor([ 9,  7,  7,  7,  7,  7,  9, 18, 18, 20, 20, 20, 20, 31,  8, 29]) False
# tensor([ 8, 29, 30, 30]) False
# tensor([20, 48, 50, 20, 48]) False
# tensor([23]) False
# tensor([21, 31,  8, 30]) False
# tensor([ 8,  8, 30, 30, 33,  8, 30, 30, 30, 30, 30, 30, 31]) False
# tensor([31, 31, 30, 20]) False
# tensor([ 5, 30,  8, 30, 30, 50, 50]) False
# tensor([29, 38, 38, 29]) False
# tensor([20,  9,  9]) False
# tensor([30, 20, 29]) False
# tensor([ 8, 29, 29, 29]) False
# tensor([31]) False
# tensor([20, 20, 20, 31, 31, 31, 31, 20, 20, 20, 20, 20, 31, 31]) False
# tensor([31, 31, 31]) False
# tensor([31, 50, 31, 31, 50, 50, 29, 31, 31, 31, 29, 29, 31]) False
# tensor([31, 20, 29, 29, 31, 31, 29, 31, 31]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([29, 31, 31, 31]) False
# tensor([50, 31, 31, 31]) False
# tensor([20]) False
# tensor([43, 29, 20, 20]) False
# tensor([20, 20, 20, 20, 20, 20, 29]) False
# tensor([20, 20, 20, 31, 31, 31]) False
# tensor([ 1,  6,  6,  6,  6, 31, 29, 31, 40, 31, 31]) False
# tensor([31, 31, 31]) False
# tensor([31, 30]) False
# tensor([1, 7, 7]) False
# tensor([29]) False
# tensor([20, 20]) False
# tensor([23]) False
# tensor([31, 40]) False
# tensor([31, 20, 31]) False
# tensor([21, 20]) False
# tensor([ 8, 48]) False
# tensor([ 1, 20, 20, 22, 20]) False
# tensor([50, 50, 31, 31, 31, 31, 48]) False
# tensor([31, 30, 31, 48, 48]) False
# tensor([ 1, 31, 29, 19]) False
# tensor([50, 44, 48, 49]) False
# tensor([31]) False
# tensor([20, 20, 20, 20, 20, 31]) False
# tensor([ 8, 31, 48, 31, 31]) False
# tensor([20, 31, 31, 48, 22, 31, 31]) False
# tensor([31, 31, 22, 20, 50]) False
# tensor([29, 31, 31, 31]) False
# tensor([48]) False
# tensor([31,  7,  7, 31, 22, 16]) False
# tensor([48, 31, 40, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([1]) False
# tensor([48, 47,  8]) False
# tensor([31, 22, 29,  8, 31]) False
# tensor([31, 21]) False
# tensor([43, 23, 48]) False
# tensor([22, 48, 22, 22, 31, 48, 50, 31, 48]) False
# tensor([ 1, 31]) False
# tensor([50]) False
# tensor([47, 31, 29, 29, 29, 29]) False
# tensor([1]) False
# tensor([29, 48, 48,  8]) False
# tensor([31, 31, 31]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([50, 31, 22,  6, 22, 50, 30, 30]) False
# tensor([38, 31, 38]) False
# tensor([22]) False
# tensor([20, 29, 21, 30]) False
# tensor([8, 1]) False
# tensor([23, 48, 48, 48, 48, 30, 48, 48, 20, 35, 48, 48]) False
# tensor([38,  6, 20]) False
# tensor([48, 48]) False
# tensor([48, 20, 48, 48, 20, 20, 20, 48, 48,  9, 48, 48, 48,  9, 20]) False
# tensor([31]) False
# tensor([20, 20, 20, 20, 20, 20, 31]) False
# tensor([ 1, 31, 31, 31, 31]) False
# tensor([30]) False
# tensor([31, 31, 31]) False
# tensor([21]) False
# tensor([48]) False
# tensor([22, 22, 22, 22]) False
# tensor([ 8, 31]) False
# tensor([ 3, 31, 22]) False
# tensor([49, 48, 22, 48, 20, 20, 48, 48, 31]) False
# tensor([33, 31, 31, 44, 29]) False
# tensor([31]) False
# tensor([50, 21, 31, 20]) False
# tensor([48]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 40, 40, 31, 41, 21, 21, 21, 21, 21,
#         21, 21, 31, 41, 40, 21, 48]) False
# tensor([31, 30, 30, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([31]) False
# tensor([31, 31, 20, 22, 22, 22, 22, 22, 22, 31]) False
# tensor([22, 16]) False
# tensor([30, 30, 31]) False
# tensor([31, 31, 29, 50]) False
# tensor([31, 31, 31, 31, 31]) False
# tensor([22,  6, 22, 33]) False
# tensor([31, 31, 31, 31, 31, 31, 31]) False
# tensor([20, 22, 21, 20, 20]) False
# tensor([31, 31, 31]) False
# tensor([30,  7]) False
# tensor([31, 31]) False
# tensor([8]) False
# tensor([30, 20, 31, 40, 29,  1, 31, 31, 30, 29,  8, 43, 30, 30]) False
# tensor([31, 31]) False
# tensor([16, 43, 22, 29, 22, 31, 42, 30, 30, 30, 29,  4]) False
# tensor([41, 31, 31]) False
# tensor([48, 48, 31, 48,  1, 48, 48, 48]) False
# tensor([48, 48]) False
# tensor([ 1, 48]) False
# tensor([48, 48]) False
# tensor([23, 31, 31]) False
# tensor([29, 20, 30, 33]) False
# tensor([50, 31,  8,  5, 31, 31, 31, 29,  8,  8]) False
# tensor([31, 29, 31, 50, 48, 31, 29, 29, 31, 29]) False
# tensor([49, 31]) False
# tensor([48, 20, 48, 20]) False
# tensor([29]) False
# tensor([29, 29,  6,  8,  2, 31, 31]) False
# tensor([20, 20, 20, 20, 31, 31, 22, 20]) False
# tensor([21, 49, 31]) False
# tensor([50, 50, 43, 50,  8, 29]) False
# tensor([31, 31, 31, 29,  1, 19]) False
# tensor([29, 41, 29]) False
# tensor([20, 31, 31, 31, 21,  6]) False
# tensor([20, 20]) False
# tensor([20, 20, 31, 30, 31]) False
# tensor([29, 29, 29, 29]) False
# tensor([31]) False
# tensor([49, 20, 48]) False
# tensor([30, 31, 31,  5, 22, 20]) False
# tensor([31, 20]) False
# tensor([20]) False
# tensor([30, 30, 30, 20, 31, 20]) False
# tensor([31, 29, 31, 31, 31, 31]) False
# tensor([48, 33, 29, 31, 31, 48,  8, 22, 22]) False
# tensor([20, 20, 31,  8,  1, 30, 30, 30, 48, 31]) False
# tensor([22, 43, 43]) False
# tensor([ 8, 20]) False
# tensor([48, 31]) False
# tensor([31, 31, 48, 31, 48, 31, 31, 20, 31, 48]) False
# tensor([31]) False
# tensor([31, 31, 31, 31, 48]) False
# tensor([31, 31, 31, 31,  8, 30]) False
# tensor([48, 48, 48, 48, 48, 40]) False
# tensor([31, 31, 48, 31]) False
# tensor([22, 31, 29, 29, 22, 29, 31, 21, 22]) False
# tensor([ 7, 29,  8, 21, 31, 31, 31]) False
# tensor([48, 22, 20, 20, 48, 31]) False
# tensor([43, 48, 24, 31, 48, 40]) False
# tensor([31, 46, 46, 46, 46, 46, 48, 31]) True
# tensor([48, 30]) False
# tensor([29, 29]) False
# tensor([38, 31, 31, 50]) False
# tensor([50, 48, 31, 31, 21, 22, 30, 30, 30, 30, 48, 48]) False
# tensor([ 1, 48, 48,  1]) False
# tensor([20, 20, 21, 47, 50, 48]) False
# tensor([50]) False
# tensor([ 8, 22, 31, 31, 20, 22, 22, 29, 29, 29, 29]) False
# tensor([31,  1,  1,  1]) False
# tensor([48, 48, 48, 40, 20, 31, 22, 40]) False
# tensor([31, 31, 31]) False
# tensor([50, 22, 48, 31, 29, 48]) False
# tensor([30, 50, 48, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([31,  8, 48, 48, 22, 22, 22]) False
# tensor([31, 30, 48, 31]) False
# tensor([48, 11, 48, 48, 31]) False
# tensor([1]) False
# tensor([48, 48, 48, 48, 48, 48, 48, 48, 48]) False
# tensor([50, 38, 38, 48]) False
# tensor([30, 29, 29, 23, 29, 29, 29, 23, 29, 29, 29]) False
# tensor([31, 31,  7]) False
# tensor([48, 48]) False
# tensor([9]) False
# tensor([31]) False
# tensor([28]) False
# tensor([20, 30, 25, 48, 48, 25]) False
# tensor([30, 30, 48]) False
# tensor([30, 31, 31]) False
# tensor([31, 31, 11]) False
# tensor([31, 31, 31]) False
# tensor([50, 31, 31, 31, 31, 29]) False
# tensor([21]) False
# tensor([40, 31, 31, 31, 31]) False
# tensor([20, 20, 20, 20]) False
# tensor([49, 49, 48, 48, 48, 48, 48, 48]) False
# tensor([31, 31, 31, 48, 48]) False
# tensor([44, 47, 29, 29, 47]) False
# tensor([31, 31, 31, 31, 31]) False
# tensor([31, 50, 30, 20]) False
# tensor([20, 31, 20]) False
# tensor([22, 11, 20, 31, 31, 48, 20, 29, 48,  8]) False
# tensor([8]) False
# tensor([31]) False
# tensor([23]) False
# tensor([14, 14, 31, 30, 21, 21, 20, 20, 31, 14, 14,  1, 48, 43, 20]) False
# tensor([22, 50, 31]) False
# tensor([47, 31, 50, 29, 29, 48]) False
# tensor([31, 31, 29, 31, 29, 29, 31, 29]) False
# tensor([31]) False
# tensor([23, 31, 23, 31, 29, 30]) False
# tensor([22]) False
# tensor([50]) False
# tensor([48, 20, 48, 48, 22]) False
# tensor([31]) False
# tensor([31, 48, 31, 48, 31, 31, 31, 48, 48, 38,  7, 48]) False
# tensor([29]) False
# tensor([30, 20, 20, 20, 30]) False
# tensor([31, 16, 16, 22, 48, 48, 48, 48, 20, 31, 48, 22, 50, 22, 22, 30, 30]) False
# tensor([29, 31, 46, 23, 31]) True
# tensor([38, 30]) False
# tensor([ 8, 29, 20, 29]) False
# tensor([40, 21, 22]) False
# tensor([31, 30, 30, 17]) False
# tensor([48, 20, 20, 20, 48, 48]) False
# tensor([31, 31]) False
# tensor([38, 46, 48,  7,  7,  7,  7,  7]) True
# tensor([49, 20]) False
# tensor([43, 20, 20, 20]) False
# tensor([21, 31, 31, 22, 48, 20, 20, 50, 50, 31]) False
# tensor([31, 31, 49]) False
# tensor([49, 44, 40, 31, 31, 44, 31, 31, 48, 22, 21, 44, 21]) False
# tensor([31, 31, 31, 31, 31,  8, 25, 48, 48, 48, 48]) False
# tensor([21, 11, 46, 11, 46, 31]) True
# tensor([29, 31]) False
# tensor([31, 31, 31]) False
# tensor([38, 38, 38, 38, 31, 48, 48]) False
# tensor([31, 31, 31]) False
# tensor([31, 48, 48, 31, 31, 30, 31]) False
# tensor([50, 22, 22]) False
# tensor([22, 22]) False
# tensor([31, 31, 31, 31, 31, 48, 31]) False
# tensor([48, 48, 30, 30, 20, 20,  8, 29, 29, 22, 22, 22, 21, 21, 31]) False
# tensor([30, 30, 30, 30]) False
# tensor([22, 31, 22, 31, 20]) False
# tensor([29, 31,  8,  8, 29, 29, 29]) False
# tensor([46]) True
# tensor([48]) False
# tensor([31, 31, 43, 31, 48, 48, 22]) False
# tensor([23, 31, 31, 31, 31, 31]) False
# tensor([23, 23, 23, 23, 23, 23, 25, 31]) False
# tensor([31,  7,  7, 31, 29, 31,  7, 31,  7,  7,  7, 31]) False
# tensor([31, 31]) False
# tensor([16]) False
# tensor([31, 50, 50, 29, 31]) False
# tensor([30, 30, 31, 31, 31, 29]) False
# tensor([41]) False
# tensor([29, 29, 40, 29, 31, 31, 29, 31, 31]) False
# tensor([31, 31, 31]) False
# tensor([50, 50]) False
# tensor([31, 22, 22, 22, 22, 31, 31, 29,  8, 31, 31, 29]) False
# tensor([31]) False
# tensor([31]) False
# tensor([31, 23, 31, 31, 31]) False
# tensor([46]) True
# tensor([31]) False
# tensor([30, 30, 29, 31, 43, 29, 20, 20]) False
# tensor([29, 22]) False
# tensor([48, 32]) False
# tensor([31, 50, 29, 31, 22]) False
# tensor([23, 32, 20, 45, 48, 48]) False
# tensor([50]) False
# tensor([31, 31, 31, 31, 31, 48, 20]) False
# tensor([31, 31, 31, 31]) False
# tensor([48, 22, 21, 48,  1, 48, 48]) False
# tensor([21, 40, 40, 48, 40, 20, 48, 20, 22, 48, 48, 20, 48, 20, 20, 21, 21, 47,
#         47, 48, 48, 48]) False
# tensor([31, 31, 31, 31, 31]) False
# tensor([31, 31, 31, 31, 31, 31, 31,  8, 31]) False
# tensor([31, 31, 29, 31, 31]) False
# tensor([31, 31, 48]) False
# tensor([31]) False
# tensor([22, 22, 31, 22, 48, 31, 31, 41, 41, 31, 31, 31, 22]) False
# tensor([48, 21, 21, 48]) False
# tensor([30, 30, 30, 30, 31]) False
# tensor([31,  6, 20, 31, 20, 31, 48, 48, 30]) False
# tensor([22, 31, 31, 31, 31, 29, 31, 31]) False
# tensor([31, 31]) False
# tensor([21, 48, 31]) False
# tensor([31, 48, 20, 48, 48]) False
# tensor([31, 31, 31, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]) False
# tensor([22, 48,  8, 20, 20]) False
# tensor([ 1, 31, 32, 31,  1, 32,  1, 43, 31]) False
# tensor([22, 31]) False
# tensor([48, 31]) False
# tensor([31, 31]) False
# tensor([22, 22, 14]) False
# tensor([40, 48, 48, 48, 48, 40, 48, 29]) False
# tensor([20, 48, 48, 31, 31]) False
# tensor([22, 48, 48, 48, 22]) False
# tensor([ 9,  9, 31, 29]) False
# tensor([20, 31]) False
# tensor([22, 50, 31, 31, 31, 31, 20, 31, 20, 31, 20, 48,  6, 50, 31, 31]) False
# tensor([48, 31]) False
# tensor([31, 31]) False
# tensor([29,  1,  8, 31]) False
# tensor([20]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([30]) False
# tensor([31]) False
# tensor([16, 29, 23, 50]) False
# tensor([33, 31]) False
# tensor([50]) False
# tensor([ 5, 31, 31, 20]) False
# tensor([22, 31]) False
# tensor([22, 20, 20, 48, 31, 48, 22, 31]) False
# tensor([20]) False
# tensor([30, 30, 31, 30, 49, 31]) False
# tensor([31, 31, 43, 31]) False
# tensor([31, 29]) False
# tensor([31, 21, 11, 48, 21, 21, 29, 48, 48, 48]) False
# tensor([43, 43]) False
# tensor([23, 29]) False
# tensor([20, 20, 20, 20, 20]) False
# tensor([31, 50]) False
# tensor([21, 48,  8]) False
# tensor([31]) False
# tensor([29, 48]) False
# tensor([31, 50]) False
# tensor([31]) False
# tensor([30, 31, 31, 31, 31, 31, 30, 29]) False
# tensor([22]) False
# tensor([48]) False
# tensor([41, 41, 41, 41, 41, 41, 41, 48]) False
# tensor([ 1,  7, 31, 31, 31, 31, 50]) False
# tensor([31, 30, 31]) False
# tensor([22, 22,  7,  1, 29]) False
# tensor([30, 30, 30, 30, 30]) False
# tensor([50, 31]) False
# tensor([31, 48, 21]) False
# tensor([22, 22]) False
# tensor([22, 43]) False
# tensor([20]) False
# tensor([20, 20, 20, 46, 46, 46, 46, 46]) True
# tensor([50, 31,  8, 48]) False
# tensor([48, 31, 50,  6, 30, 30, 30]) False
# tensor([20, 31, 31, 29]) False
# tensor([29, 31, 31, 31, 31, 31, 31, 48, 50, 22]) False
# tensor([48]) False
# tensor([20]) False
# tensor([20, 48, 48,  1, 20, 48, 31, 31, 20, 20, 31, 20, 20]) False
# tensor([31, 31, 31]) False
# tensor([31,  9,  9,  9,  9, 48]) False
# tensor([31, 48, 48, 20, 48, 48, 31]) False
# tensor([50, 31, 50, 50, 31]) False
# tensor([31, 48, 23, 48, 48, 50, 31]) False
# tensor([48, 48, 48, 48]) False
# tensor([48]) False
# tensor([20, 20,  1, 31, 29, 40, 43, 30]) False
# tensor([41]) False
# tensor([30, 30, 48, 48, 48, 20, 48, 48, 48, 22]) False
# tensor([31, 31,  7, 22]) False
# tensor([ 1, 31, 31, 20, 20]) False
# tensor([50,  8, 21, 21, 30, 30, 22, 22, 50, 48, 21]) False
# tensor([31, 29, 48]) False
# tensor([31, 21]) False
# tensor([22, 50, 31, 48, 21]) False
# tensor([21, 31, 30, 30, 21]) False
# tensor([31, 31, 48, 29, 31, 48, 31, 48, 31, 20, 48, 48]) False
# tensor([29]) False
# tensor([ 1, 31, 22, 31, 31]) False
# tensor([29, 29, 29]) False
# tensor([48, 13, 22, 50]) False
# tensor([31, 25, 25, 31, 31, 31, 31, 48, 48, 40]) False
# tensor([31, 30]) False
# tensor([29, 20, 31, 31]) False
# tensor([31, 31, 31]) False
# tensor([31,  8]) False
# tensor([31, 31, 31]) False
# tensor([43, 22]) False
# tensor([ 9,  9, 48,  7]) False
# tensor([20, 48, 48]) False
# tensor([20]) False
# tensor([31]) False
# tensor([22, 31, 31, 46, 20, 31, 30]) True
# tensor([12]) False
# tensor([30, 48]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 40, 40]) False
# tensor([30, 31, 20]) False
# tensor([31]) False
# tensor([20]) False
# tensor([22, 22, 31, 31, 31, 48, 31, 30, 31, 22, 48, 48, 48]) False
# tensor([50, 31, 31, 31, 42]) False
# tensor([30, 30]) False
# tensor([31, 31, 31]) False
# tensor([31]) False
# tensor([22]) False
# tensor([30, 31, 31]) False
# tensor([20, 23]) False
# tensor([48, 48, 20, 21]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31,  7, 31, 33, 30]) False
# tensor([ 1, 31, 20]) False
# tensor([30]) False
# tensor([23, 48, 48, 19, 31]) False
# tensor([31, 31, 31, 31]) False
# tensor([30, 31]) False
# tensor([30, 30,  8]) False
# tensor([31, 31, 31,  7,  7, 20, 31, 31, 31]) False
# tensor([31]) False
# tensor([31]) False
# tensor([29]) False
# tensor([31, 31, 48, 29, 31]) False
# tensor([8]) False
# tensor([20,  8, 31]) False
# tensor([31]) False
# tensor([46, 46, 46, 46, 22, 49]) True
# tensor([31, 31, 22, 48, 31, 23, 48]) False
# tensor([21, 20, 20, 21, 20, 20, 31, 23, 48]) False
# tensor([31]) False
# tensor([29, 38, 31, 31, 29, 31, 22, 31, 31, 31, 31, 31, 31, 30, 30]) False
# tensor([20, 23, 29, 29]) False
# tensor([30, 30, 21, 21, 21, 22, 22, 21, 31, 48]) False
# tensor([21, 41, 22]) False
# tensor([20, 20, 20, 20, 20, 20, 31]) False
# tensor([31, 31, 48]) False
# tensor([31, 29]) False
# tensor([31, 31, 48, 48, 48, 31]) False
# tensor([20]) False
# tensor([22, 31, 29, 21, 31, 29]) False
# tensor([31, 31, 31, 31, 40, 50, 31, 30, 50, 31, 31]) False
# tensor([29, 20, 48, 48, 29, 29, 31]) False
# tensor([31, 48, 31, 22, 31, 31, 48, 50, 21, 48, 48, 48, 48, 48, 31, 11, 22, 31,
#         29, 31]) False
# tensor([10]) False
# tensor([48, 48, 48, 48, 48, 48, 48, 11]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([30, 31, 31, 22, 22, 22, 31, 31, 31, 31, 31, 31, 31, 31, 31, 22]) False
# tensor([31]) False
# tensor([48, 48]) False
# tensor([30, 31, 31]) False
# tensor([31, 31, 48, 48]) False
# tensor([30]) False
# tensor([48, 48]) False
# tensor([31, 31, 50, 29]) False
# tensor([30, 30, 30, 30, 48, 48, 48, 48]) False
# tensor([48, 48, 40, 48, 22, 48, 30, 22, 31]) False
# tensor([22]) False
# tensor([30, 50, 48]) False
# tensor([8]) False
# tensor([31, 31, 49, 49, 40, 20]) False
# tensor([43]) False
# tensor([22,  7]) False
# tensor([8]) False
# tensor([31]) False
# tensor([31, 31, 31, 31]) False
# tensor([43, 31, 31, 31, 31, 31, 40, 50, 31, 31, 29]) False
# tensor([31]) False
# tensor([20, 20, 20, 31]) False
# tensor([31, 31, 48]) False
# tensor([29, 42,  8]) False
# tensor([29, 30, 20, 20, 31, 30]) False
# tensor([22, 22, 22, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([48, 48, 50, 48, 48, 48, 48, 21, 50, 50, 30]) False
# tensor([31, 31, 48, 48, 48, 48, 40, 48, 48, 48, 48]) False
# tensor([50, 30, 30]) False
# tensor([30, 30, 30, 48, 48, 48, 48, 48]) False
# tensor([22, 22, 31,  8, 31, 31, 50, 48, 50, 31]) False
# tensor([48, 31, 31, 31, 31, 31, 31]) False
# tensor([31]) False
# tensor([31, 48, 29]) False
# tensor([22, 33, 33, 31]) False
# tensor([31, 29, 31]) False
# tensor([48,  7,  7]) False
# tensor([48, 31, 31, 31, 31, 31, 48, 48, 48, 48, 31, 48, 31, 20, 48, 48, 49, 48]) False
# tensor([31, 48, 48, 50]) False
# tensor([31, 20]) False
# tensor([31]) False
# tensor([7]) False
# tensor([31, 40, 40, 40, 48, 40]) False
# tensor([31, 31]) False
# tensor([43]) False
# tensor([31]) False
# tensor([22, 48, 48, 48, 48, 48, 48, 22]) False
# tensor([48]) False
# tensor([48, 48, 31, 48, 48, 22,  1]) False
# tensor([31, 23, 46, 31, 31, 46, 46, 46, 46, 20]) True
# tensor([21, 20, 41, 31, 21, 29, 29]) False
# tensor([31,  1, 43, 31, 31, 31]) False
# tensor([31, 43, 31, 31, 31]) False
# tensor([29, 41, 48, 30]) False
# tensor([22, 22,  7,  7]) False
# tensor([38,  1, 49, 20, 49, 49, 49]) False
# tensor([31]) False
# tensor([31, 30, 31, 31, 19, 33]) False
# tensor([20, 31, 22]) False
# tensor([48, 29, 22, 31, 48, 48, 49]) False
# tensor([ 6, 30, 22, 30, 30]) False
# tensor([48, 48, 20, 20, 20, 48, 48]) False
# tensor([20]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([48, 31, 29]) False
# tensor([31, 31,  1, 31, 31]) False
# tensor([31, 31, 31,  8,  8]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 20, 20]) False
# tensor([48, 48, 24, 50, 22]) False
# tensor([50, 50, 50, 50, 48, 50, 22, 50]) False
# tensor([30, 30, 48, 22,  5, 22, 31, 31, 31, 30, 20, 48, 31, 31, 20, 31, 31]) False
# tensor([30]) False
# tensor([31,  6, 31, 31, 31, 31]) False
# tensor([31, 25]) False
# tensor([31, 31, 31, 31, 31]) False
# tensor([20, 48, 48]) False
# tensor([20, 20, 31, 31, 30, 48, 48, 21, 48, 31, 20]) False
# tensor([31, 31, 31, 31, 31, 31, 22, 22, 22, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([48, 30, 30]) False
# tensor([30, 48, 20, 20, 31, 29, 31]) False
# tensor([31, 31, 20, 30, 30, 30, 31, 43, 44, 20, 20, 20]) False
# tensor([31, 31, 31]) False
# tensor([31]) False
# tensor([30]) False
# tensor([31]) False
# tensor([21, 41]) False
# tensor([43, 31, 31]) False
# tensor([31, 31]) False
# tensor([48, 48,  9, 31, 21, 41, 48, 20]) False
# tensor([21, 29, 31,  8, 48, 48, 48,  8]) False
# tensor([48]) False
# tensor([47, 50, 50, 31]) False
# tensor([31]) False
# tensor([31, 31, 31, 31, 31]) False
# tensor([31, 20, 31, 31, 31, 31]) False
# tensor([31]) False
# tensor([20, 31, 31]) False
# tensor([30, 30, 29]) False
# tensor([22]) False
# tensor([48, 31, 31, 31, 31, 20, 50, 48, 48, 20, 31, 31, 31, 31, 48, 48, 31, 31]) False
# tensor([ 1,  7, 40]) False
# tensor([31, 20]) False
# tensor([48, 31, 31, 31, 48, 48, 48, 31, 31,  6, 31, 31, 50]) False
# tensor([ 1, 23]) False
# tensor([20,  1]) False
# tensor([20, 29, 29, 29, 31]) False
# tensor([31, 31, 31, 31, 31]) False
# tensor([31]) False
# tensor([29]) False
# tensor([22, 31,  8,  8, 19, 19, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([31, 31, 31, 31, 31]) False
# tensor([31, 31, 48]) False
# tensor([11, 29, 20, 31, 30, 31]) False
# tensor([30, 31, 31, 29]) False
# tensor([19, 22, 20, 20, 49, 49, 49]) False
# tensor([21, 31, 31]) False
# tensor([48, 22, 31, 29, 31, 31, 31, 31, 31]) False
# tensor([31, 31, 48]) False
# tensor([20, 31, 30,  8, 31, 50,  8]) False
# tensor([31, 31, 31, 31, 29, 31, 31, 31]) False
# tensor([30, 20, 20, 20, 20, 20, 20]) False
# tensor([31, 31, 48, 48, 48, 48, 48, 30, 31, 30, 30, 30]) False
# tensor([22, 31, 31, 31, 48]) False
# tensor([21, 21, 48, 48, 48, 48, 48, 31, 31, 50, 21, 50]) False
# tensor([31, 30, 29,  8]) False
# tensor([31, 31]) False
# tensor([41, 41, 41, 41, 48, 22]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 29, 10, 10]) False
# tensor([31, 10, 31, 31]) False
# tensor([21, 31, 31, 31, 31, 31, 31, 22, 22, 22, 22, 50]) False
# tensor([ 8,  8,  8,  8,  8, 20, 30, 31]) False
# tensor([22]) False
# tensor([31]) False
# tensor([31, 31]) False
# tensor([29, 31, 31, 20, 20]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31,
#         31, 30, 30, 30, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([31, 31]) False
# tensor([41, 48, 29, 31, 31]) False
# tensor([31]) False
# tensor([31, 31, 30, 31]) False
# tensor([31, 22, 48, 22, 20, 20, 31, 31, 31, 31, 31, 31, 22]) False
# tensor([31]) False
# tensor([24,  7, 48, 31, 31, 31, 25, 31]) False
# tensor([31, 48, 48, 48, 48, 48, 48, 31, 31]) False
# tensor([21, 48, 21, 22, 50, 50, 21, 50, 48, 48, 21, 46]) True
# tensor([31]) False
# tensor([30,  1]) False
# tensor([29, 29, 31]) False
# tensor([20, 49, 49, 22, 20]) False
# tensor([49, 38]) False
# tensor([46, 46, 46, 31, 31]) True
# tensor([31]) False
# tensor([48, 44, 31, 22, 31, 20, 31, 31, 20]) False
# tensor([30, 31, 48, 31, 22, 31, 20]) False
# tensor([31]) False
# tensor([48, 50, 48, 31]) False
# tensor([13, 29, 23, 31, 31, 29, 31]) False
# tensor([ 9,  1, 48, 48, 48, 48, 48, 31, 31, 29, 29, 29]) False
# tensor([20, 30, 43]) False
# tensor([30, 31]) False
# tensor([31, 31, 31, 20, 31]) False
# tensor([31, 29, 31]) False
# tensor([31, 29, 48, 40, 40]) False
# tensor([29, 48, 48, 48, 48, 48, 48, 48, 48]) False
# tensor([31, 31, 31, 31, 31, 31]) False
# tensor([22, 48,  1]) False
# tensor([21, 48, 31, 31, 31, 22, 48, 48, 48, 22]) False
# tensor([ 7,  7,  7,  7,  7,  7, 48, 48, 48, 48, 48, 49, 49, 20, 48, 48, 48, 48]) False
# tensor([38, 30, 31]) False
# tensor([31, 31, 31, 48, 48, 48, 48, 48, 12]) False
# tensor([31]) False
# tensor([ 2, 23, 31, 31, 31, 31, 31, 31, 31, 31, 31, 20, 41]) False
# tensor([31]) False
# tensor([31, 31, 31, 22]) False
# tensor([49, 20, 49, 48, 20, 31, 31, 40]) False
# tensor([31, 31, 31, 31, 31, 31, 31]) False
# tensor([30, 31]) False
# tensor([43, 31, 31]) False
# tensor([31, 31, 31, 31, 40, 40, 31, 40, 29, 22, 20, 20, 20, 20, 20, 40, 40, 31,
#         22, 31]) False
# tensor([31, 31, 30, 31, 31, 30,  8,  8, 50, 50,  6]) False
# tensor([31, 31]) False
# tensor([48, 20, 48, 48, 21, 48]) False
# tensor([48, 48]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31,  8]) False
# tensor([41, 41]) False
# tensor([31, 21, 48, 20, 20, 20, 31, 31, 31, 31, 22, 31, 31]) False
# tensor([31, 31, 31, 31, 31]) False
# tensor([50, 50]) False
# tensor([31, 40]) False
# tensor([ 8,  1, 48, 48, 48, 31]) False
# tensor([48, 48, 48, 48,  8,  8, 38]) False
# tensor([31, 21, 49, 20]) False
# tensor([29, 29, 29]) False
# tensor([29, 31, 31, 29, 29]) False
# tensor([31, 20]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 22]) False
# tensor([31, 31, 31, 48]) False
# tensor([31, 20, 30, 20, 30, 20]) False
# tensor([20, 21, 20, 49, 31, 31, 22]) False
# tensor([20, 20, 31, 22, 50, 31, 22, 30]) False
# tensor([43]) False
# tensor([22, 41, 22, 22, 22, 31, 31]) False
# tensor([22, 20, 30, 30, 30, 31, 31]) False
# tensor([31, 20, 20]) False
# tensor([21,  9,  7]) False
# tensor([48, 40, 40, 29, 50]) False
# tensor([31, 30, 31, 22,  1, 48, 41, 31, 30]) False
# tensor([29, 29]) False
# tensor([31]) False
# tensor([22, 48, 40]) False
# tensor([22]) False
# tensor([22, 31]) False
# tensor([ 8,  8, 22,  1, 41]) False
# tensor([31, 31, 31]) False
# tensor([ 8, 31, 31, 48, 48, 48]) False
# tensor([22, 30, 31]) False
# tensor([21, 48, 29, 31, 48, 48, 19]) False
# tensor([48, 41, 12, 22, 48, 48, 48, 48, 48, 29]) False
# tensor([20, 29, 29,  1, 20, 20]) False
# tensor([31, 29]) False
# tensor([34]) False
# tensor([46, 50, 29, 31, 29,  7, 31]) True
# tensor([48, 20, 20, 20, 31, 31]) False
# tensor([33, 31]) False
# tensor([48, 31, 30, 30, 48, 48]) False
# tensor([22, 22, 31, 22, 21,  8,  8]) False
# tensor([48, 25, 50]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([20, 20, 49,  8, 22, 31, 21]) False
# tensor([31, 31,  6, 29,  6,  6]) False
# tensor([31, 31]) False
# tensor([49, 31]) False
# tensor([20, 50, 50]) False
# tensor([31, 31]) False
# tensor([48, 48, 48,  6,  6, 31, 31, 31, 48, 31, 22]) False
# tensor([ 1, 20, 20, 20, 31, 29]) False
# tensor([50, 22, 50]) False
# tensor([48, 48, 21, 48,  7]) False
# tensor([50, 22, 10, 10, 22,  8]) False
# tensor([21, 48, 22,  7, 48, 29]) False
# tensor([ 8, 48, 30, 30, 30, 40, 48, 50]) False
# tensor([47, 47, 47, 47, 47, 47]) False
# tensor([21, 31]) False
# tensor([8, 8]) False
# tensor([31, 31, 31, 31, 31, 22, 29, 22, 20, 22, 10]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([31, 31, 48, 22, 46, 46, 46]) True
# tensor([49, 30, 31]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([22, 31,  1]) False
# tensor([ 7, 31]) False
# tensor([20, 48, 48, 31, 31, 31, 48, 49, 31, 31, 31, 31]) False
# tensor([31, 48, 48, 31, 48, 20, 29, 48, 48, 30, 31, 30, 30, 30, 22, 48, 48, 48,
#         48, 20, 31]) False
# tensor([31, 31, 31]) False
# tensor([31, 31, 31, 31, 31, 31]) False
# tensor([30, 23]) False
# tensor([29]) False
# tensor([50, 31, 41, 48]) False
# tensor([50, 40,  1]) False
# tensor([50, 48, 48, 48, 22, 38, 31, 31, 31, 31, 18, 31]) False
# tensor([21,  1, 48,  7,  1, 21,  1, 31, 11, 22]) False
# tensor([40, 31, 31, 31]) False
# tensor([48, 31, 22]) False
# tensor([31, 20]) False
# tensor([20, 20, 20, 22, 20, 31, 31, 31, 31, 31, 50, 29, 50, 21, 31, 22]) False
# tensor([20, 31, 47, 31, 47]) False
# tensor([50]) False
# tensor([48, 48, 21, 48, 48, 48, 48, 20, 48, 48, 29, 31, 31, 31, 31]) False
# tensor([50, 50, 22]) False
# tensor([ 1, 43, 33, 49, 21, 22]) False
# tensor([23, 31, 31, 23, 20, 31, 31]) False
# tensor([35, 35, 35, 35, 35, 46, 31, 22, 31, 31, 31, 31, 43, 50, 29, 23, 31]) True
# tensor([31, 50,  2, 31, 31]) False
# tensor([31, 31, 41, 31, 41, 22, 48, 31, 31]) False
# tensor([31, 48,  8, 31, 30, 31]) False
# tensor([ 8, 21, 21, 48, 48]) False
# tensor([40, 31, 31, 31, 31]) False
# tensor([21, 31, 22, 22, 22, 22, 22, 22, 22, 22, 22]) False
# tensor([48, 31, 48]) False
# tensor([31, 31, 31, 29, 31, 31, 31, 31, 31, 20, 20]) False
# tensor([50]) False
# tensor([31, 22, 22, 22]) False
# tensor([29, 22]) False
# tensor([50, 50, 48]) False
# tensor([31, 31]) False
# tensor([31, 31, 20, 29,  8, 31, 22]) False
# tensor([20, 20, 29, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 29, 29, 29,
#         29]) False
# tensor([31]) False
# tensor([48, 48, 20, 20, 48, 48, 48, 48, 31, 38]) False
# tensor([31, 30]) False
# tensor([48, 48, 22, 21, 48, 22, 11, 11, 50, 50, 50, 48]) False
# tensor([13, 13, 13, 13, 13]) False
# tensor([31, 31, 31, 31, 31, 31, 31]) False
# tensor([31, 20]) False
# tensor([31, 31, 29, 20, 20]) False
# tensor([31]) False
# tensor([31, 31, 31, 20, 31, 20, 20]) False
# tensor([31, 48, 48, 48, 48, 48, 48, 31, 22, 31, 31, 31, 31, 31, 31, 31, 31, 48,
#         22, 48]) False
# tensor([31, 31]) False
# tensor([31, 41, 41, 48, 48, 48, 48, 31, 22]) False
# tensor([20]) False
# tensor([20, 48, 48, 48, 48, 19, 46, 46, 46]) True
# tensor([48, 48, 48, 48, 31, 46, 23, 31]) True
# tensor([22, 31, 31, 20]) False
# tensor([29, 31, 31, 31]) False
# tensor([31]) False
# tensor([48, 40, 48, 29, 40, 21, 22, 21, 48, 31]) False
# tensor([31, 31, 31, 20, 48, 20, 20]) False
# tensor([31, 31, 31, 31, 31]) False
# tensor([31, 31]) False
# tensor([31, 48, 48, 48, 20, 48, 31, 48, 31, 50]) False
# tensor([48, 48, 11, 20, 47, 48, 48, 22, 22, 22, 31, 31, 31, 31, 31]) False
# tensor([31]) False
# tensor([30]) False
# tensor([31, 48, 48, 48, 49, 30]) False
# tensor([31, 31, 31, 22]) False
# tensor([ 8, 48, 48, 48, 48]) False
# tensor([ 7, 48, 31, 21]) False
# tensor([31, 29, 48, 50, 20, 20, 48, 31, 22, 32, 50, 29, 30]) False
# tensor([48, 48,  8,  8,  8, 31,  1,  1, 20, 28, 48, 31]) False
# tensor([50]) False
# tensor([31, 31, 31]) False
# tensor([20, 48]) False
# tensor([38, 31, 31, 31,  8, 46]) True
# tensor([48, 48]) False
# tensor([21, 21,  1,  1,  1, 48]) False
# tensor([ 1, 21, 31, 31]) False
# tensor([31, 31, 31, 48, 22, 31, 31, 31]) False
# tensor([31, 31]) False
# tensor([48, 30, 30, 31, 31, 30, 31, 48]) False
# tensor([31, 31, 31, 31, 31, 31, 31]) False
# tensor([50, 31, 31, 19]) False
# tensor([31]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([48, 40]) False
# tensor([31, 31, 20, 31]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 48]) False
# tensor([31, 31]) False
# tensor([31, 49, 49, 31, 49, 31, 50, 48, 48, 31, 48, 48]) False
# tensor([31, 41]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([ 6, 29]) False
# tensor([33, 31, 31, 31, 31]) False
# tensor([20, 31, 31]) False
# tensor([30, 31,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,  7,
#          7,  7,  7,  7,  7,  7,  7,  7,  7,  7]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([48, 48, 48, 48, 31, 31, 48, 48,  9, 31, 48, 20, 31, 31]) False
# tensor([14, 20, 20, 20, 31, 20]) False
# tensor([13, 31, 50, 31, 48, 22, 22, 22, 22, 22, 31, 31, 31, 31, 30, 20]) False
# tensor([29, 31, 29]) False
# tensor([ 1, 14,  8, 14]) False
# tensor([31, 31]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 29, 35, 31]) False
# tensor([31, 31, 29, 48]) False
# tensor([31]) False
# tensor([31, 31, 29, 31, 31]) False
# tensor([30]) False
# tensor([31]) False
# tensor([31, 31, 31]) False
# tensor([31, 29, 20]) False
# tensor([29,  1, 29]) False
# tensor([31, 31, 31, 31, 31, 31, 29, 31, 31, 31, 31, 31]) False
# tensor([31, 31, 22, 31]) False
# tensor([31]) False
# tensor([29, 31, 31]) False
# tensor([29, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([29]) False
# tensor([31]) False
# tensor([22, 22, 40]) False
# tensor([35, 31, 48, 23, 23, 31]) False
# tensor([ 7,  7, 29, 23]) False
# tensor([29, 29, 29, 48, 20, 48, 20,  8, 48, 48]) False
# tensor([22, 20, 20, 20, 20, 29, 29, 40, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([48, 20, 31, 31, 41, 31]) False
# tensor([31, 31]) False
# tensor([31]) False
# tensor([31, 31, 31, 31]) False
# tensor([48, 48, 31, 31, 19]) False
# tensor([31, 48, 31]) False
# tensor([31, 31, 31, 31, 29, 29,  8, 23]) False
# tensor([ 8, 31, 31, 31, 48]) False
# tensor([23, 22, 29]) False
# tensor([31, 31, 30, 31, 31, 31, 43,  8]) False
# tensor([31]) False
# tensor([29, 48, 48, 48, 48, 20, 50]) False
# tensor([30]) False
# tensor([31, 50, 31, 48, 21, 50, 31, 50, 31, 48, 31, 48, 31, 48, 43, 31, 46, 43,
#         31]) True
# tensor([22, 22, 40, 22]) False
# tensor([22, 31, 31, 31, 50, 22]) False
# tensor([ 1, 31, 43, 31, 25, 43]) False
# tensor([48]) False
# tensor([34, 31, 30, 29, 50]) False
# tensor([20, 31]) False
# tensor([ 8,  8,  8, 48, 40, 31, 40]) False
# tensor([31]) False
# tensor([31]) False
# tensor([48, 21, 22, 31]) False
# tensor([48]) False
# tensor([20, 31, 31, 43, 31, 22, 31,  8]) False
# tensor([31, 30, 31, 31, 38, 48, 31, 31,  7]) False
# tensor([41, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([48,  8, 48]) False
# tensor([ 8, 48, 48, 21, 22]) False
# tensor([31, 31, 31, 31, 31]) False
# tensor([31, 48, 48, 48, 31, 31, 31, 31, 31]) False
# tensor([31, 50,  6]) False
# tensor([30, 31, 30, 30]) False
# tensor([31, 30, 30, 29]) False
# tensor([48]) False
# tensor([48, 50, 50, 50, 50, 50]) False
# tensor([8]) False
# tensor([48, 48, 20, 50]) False
# tensor([48, 20, 48, 48,  8,  8,  8,  8,  8,  8,  8, 40, 20, 20, 20]) False
# tensor([21, 50, 43, 16, 43, 50, 50, 20, 21, 21, 48, 20]) False
# tensor([30, 30, 30, 31, 50, 48, 48, 31,  1, 22, 50, 50]) False
# tensor([31]) False
# tensor([19, 31, 31]) False
# tensor([30, 30]) False
# tensor([31, 31, 31, 31, 48]) False
# tensor([49, 40, 24, 31]) False
# tensor([22, 22, 31, 31, 31, 31]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([20, 31, 31, 31]) False
# tensor([48, 21, 21, 31, 50]) False
# tensor([48, 48, 50, 31, 21, 50, 31, 31, 31, 35, 31, 22, 31, 31]) False
# tensor([48, 48, 22, 31]) False
# tensor([33, 40, 40, 21, 40]) False
# tensor([50, 31, 31, 31]) False
# tensor([48, 30, 30, 30, 30, 30, 30, 30]) False
# tensor([23, 31]) False
# tensor([ 1, 30, 20,  8, 20, 20]) False
# tensor([31, 31, 31, 31, 30, 31, 50]) False
# tensor([31]) False
# tensor([41]) False
# tensor([48,  9, 31, 48, 50, 31]) False
# tensor([31]) False
# tensor([50, 50, 22, 31, 48, 48, 31, 48]) False
# tensor([50, 50, 50]) False
# tensor([20, 31, 31]) False
# tensor([22]) False
# tensor([22, 31, 22, 31]) False
# tensor([50, 22, 22, 22]) False
# tensor([31, 31, 31, 31]) False
# tensor([22, 31, 29, 29, 22]) False
# tensor([48, 48, 31]) False
# tensor([22]) False
# tensor([48]) False
# tensor([ 6,  8, 21, 33, 29, 31, 50]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([30, 30, 22, 21, 48, 48, 31, 31, 31, 31, 48]) False
# tensor([31, 31, 31, 48]) False
# tensor([31]) False
# tensor([31]) False
# tensor([31, 30, 30, 48]) False
# tensor([29, 31, 32,  8, 31]) False
# tensor([31, 31, 31, 31, 31,  8, 20, 31,  8, 31, 31, 50]) False
# tensor([48]) False
# tensor([48, 48, 50, 50, 31]) False
# tensor([31, 21]) False
# tensor([48, 21]) False
# tensor([ 7,  7,  7,  7, 22, 31, 48, 31]) False
# tensor([30, 31, 31, 31, 31, 31, 31, 20, 31, 20, 20, 20]) False
# tensor([31, 31, 31, 31, 31, 31, 31]) False
# tensor([20, 20, 48, 48, 48]) False
# tensor([50, 22, 29, 22, 22, 50]) False
# tensor([31,  8, 20, 20, 20]) False
# tensor([31]) False
# tensor([22, 31, 29, 29, 31]) False
# tensor([31, 22, 48, 48, 31, 31, 31, 31, 31, 31]) False
# tensor([21, 21, 21, 31, 11, 48, 48, 48, 48, 48]) False
# tensor([31, 29, 29, 22, 40, 31, 31, 20]) False
# tensor([22]) False
# tensor([22, 22, 16, 16, 48, 48, 48, 48, 41, 31, 31, 30, 30, 30]) False
# tensor([22, 31, 31,  3,  8, 31,  1, 31, 31, 29]) False
# tensor([30, 22, 21, 48, 40]) False
# tensor([20, 20, 20, 20]) False
# tensor([50, 31, 50, 31, 31, 43]) False
# tensor([31, 31, 31, 48, 48]) False
# tensor([48, 50, 31]) False
# tensor([22, 31, 20, 31]) False
# tensor([22]) False
# tensor([41, 22, 20, 20, 20, 20, 41, 41]) False
# tensor([31, 31, 31]) False
# tensor([43, 33, 31]) False
# tensor([31, 48]) False
# tensor([43, 31, 22, 20, 31, 31]) False
# tensor([31, 19, 48]) False
# tensor([31, 31, 31, 33, 48, 31, 31, 31,  7, 48, 31, 31, 31]) False
# tensor([31,  6,  8, 31, 31, 31, 31, 30, 31, 31, 41, 31, 31, 31, 31, 31, 31, 31,
#         29]) False
# tensor([29, 22, 22, 22, 48]) False
# tensor([31, 31, 31]) False
# tensor([21, 30, 22, 21, 21, 48, 50, 30, 21]) False
# tensor([31, 20, 31]) False
# tensor([22, 21, 31, 31, 48, 46, 31]) True
# tensor([31, 20, 20, 20, 20, 31, 43]) False
# tensor([44, 48, 50, 31, 31, 31, 48, 31, 31]) False
# tensor([30, 31, 31, 31, 30, 30, 31, 31]) False
# tensor([20, 22, 50, 50]) False
# tensor([31, 31, 31]) False
# tensor([50, 50, 31, 29, 29]) False
# tensor([48, 48, 31, 13, 21, 31, 31, 31, 31]) False
# tensor([31, 31, 30, 31, 31]) False
# tensor([48, 48, 48, 21, 48, 48]) False
# tensor([20, 20, 50, 30, 31]) False
# tensor([34, 31,  7]) False
# tensor([31, 31, 31, 23, 22, 30]) False
# tensor([31, 48, 48]) False
# tensor([31, 31, 31]) False
# tensor([20, 20, 20, 30, 30, 20, 48, 20, 20, 31, 40, 48, 48,  8, 20, 20, 20, 20,
#         30, 20, 20, 30, 30, 31, 31]) False
# tensor([20, 10, 22, 31, 13]) False
# tensor([20, 20, 20, 20, 20, 48, 20]) False
# tensor([38, 40, 20, 31, 31, 31, 31, 31, 31]) False
# tensor([48, 48, 48, 22,  8]) False
# tensor([21]) False
# tensor([31]) False
# tensor([31, 31, 31, 31, 31, 31]) False
# tensor([30, 30, 31]) False
# tensor([48, 31]) False
# tensor([31]) False
# tensor([48, 48, 48, 31, 22]) False
# tensor([43, 31, 31]) False
# tensor([31, 31, 31, 31, 31, 31, 31]) False
# tensor([48, 31, 31]) False
# tensor([31]) False
# tensor([30]) False
# tensor([22, 40]) False
# tensor([50, 40]) False
# tensor([30]) False
# tensor([21, 48, 20, 29, 48, 21, 22, 50, 22, 22, 22, 31, 31, 48]) False
# tensor([44, 40, 31]) False
# tensor([22, 22, 22, 20]) False
# tensor([48, 50, 48, 31, 50, 31, 48, 48, 50, 48]) False
# tensor([31, 31, 48, 22, 38, 40, 48, 48, 38, 31, 31, 48, 30, 20]) False
# tensor([31, 31, 31, 31]) False
# tensor([23, 23, 23, 23, 23, 31, 31, 31, 31, 31, 31, 31, 31, 50]) False
# tensor([20, 31, 31, 31, 31, 31]) False
# tensor([20, 31, 31]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 23, 22, 30, 29]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([31, 28, 31, 31, 31, 31, 31]) False
# tensor([21, 21, 20, 21, 21, 21, 21, 21, 20, 21, 21]) False
# tensor([ 1,  1,  1,  1,  1,  1,  1, 31, 31]) False
# tensor([31, 31, 41]) False
# tensor([31, 20]) False
# tensor([31, 31, 31, 20, 31,  3]) False
# tensor([8]) False
# tensor([20, 20, 20, 20, 31, 20, 31, 20, 20, 31, 20, 29, 31, 29, 31, 31]) False
# tensor([21, 21, 20, 31]) False
# tensor([20, 20, 20, 20, 20, 48, 30]) False
# tensor([ 8, 41, 43]) False
# tensor([31]) False
# tensor([23]) False
# tensor([20]) False
# tensor([29]) False
# tensor([31]) False
# tensor([31, 31, 31, 31, 20, 23, 31]) False
# tensor([20, 31]) False
# tensor([48, 31, 31, 48, 48, 48, 40, 48, 48, 31, 31, 48]) False
# tensor([ 8, 49, 31]) False
# tensor([31, 20, 31, 31, 31, 31]) False
# tensor([31, 31, 31, 31]) False
# tensor([31, 48, 31, 48, 31, 31, 31, 21]) False
# tensor([31]) False
# tensor([31, 22]) False
# tensor([25, 25, 25, 25, 25, 25, 25, 25, 25, 25]) False
# tensor([31, 48]) False
# tensor([31, 20, 20, 20]) False
# tensor([31, 31,  1]) False
# tensor([48, 31, 20, 20]) False
# tensor([31, 50, 31, 31]) False
# tensor([ 1, 31]) False
# tensor([29, 29, 29, 29, 23, 31]) False
# tensor([31, 20, 20, 21, 50]) False
# tensor([22, 50]) False
# tensor([31, 31, 31, 31]) False
# tensor([29, 29, 29]) False
# tensor([31]) False
# tensor([48, 48, 48, 48, 50, 48, 48, 50, 48, 48, 19,  1]) False
# tensor([31]) False
# tensor([30, 30, 30, 30, 30, 30]) False
# tensor([21, 31]) False
# tensor([31, 21, 31, 21, 48, 48, 48, 48, 21, 21, 21, 21, 48]) False
# tensor([31, 31, 50, 20, 31]) False
# tensor([31]) False
# tensor([48, 48, 48, 22, 22, 31, 31, 48, 48, 48]) False
# tensor([41, 41, 41, 48]) False
# tensor([31, 31]) False
# tensor([30, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([20, 21, 21, 48, 48, 48, 48, 31, 31, 31, 31]) False
# tensor([31, 31, 31, 22, 31, 22, 31, 31, 31, 20, 22, 50]) False
# tensor([50, 22, 50, 50, 50, 31, 22, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([31, 50, 48, 48, 29, 29, 29, 29, 29, 48, 40, 48, 29]) False
# tensor([31, 31, 31, 31, 31, 31, 48]) False
# tensor([48, 48, 48, 48, 48]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([8]) False
# tensor([48, 31, 31]) False
# tensor([ 1,  1, 31, 31, 31, 31, 31, 31, 31, 31]) False
# tensor([48, 48, 48, 48, 21, 48, 48, 21, 48, 48, 50, 22, 22, 22, 31, 31]) False
# tensor([31]) False
# tensor([48, 40, 50, 48, 48, 29, 21, 48, 21, 50, 48, 31, 22, 30]) False
# tensor([31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 31, 46]) True

# %%
import os,glob

wo_sample_idx=random.sample(include_wo_samples,2)
other_sample_idx=random.choice(others)

for sample_id in wo_sample_idx+[other_sample_idx]:
    img=cv2.imread(filenames[sample_id])
    target=get_groundtruth(sample_id)
    
    os.makedirs(str(sample_id),exist_ok=True)
    
    for box,cls in zip(gt_boxes[sample_id],gt_classes[sample_id]):
        obj_img=img[int(box[1]):int(box[3]),int(box[0]):int(box[2]),...]
        if os.path.exists(f'{ind_to_classes[cls]}.png'):
            exist_num=len(glob.glob(f'{sample_id}/{ind_to_classes[cls]}*.png'))
            cv2.imwrite(f'{sample_id}/{ind_to_classes[cls]}-{exist_num}.png',obj_img)
        else:
            cv2.imwrite(f'{sample_id}/{ind_to_classes[cls]}.png',obj_img)

    cv2.imwrite(f'{sample_id}/ori_img.png',img)

# %%
sample_ids=[360,432,535]
for sample_id in sample_ids:
    target=get_groundtruth(sample_id)
    rel_tuple=target.get_field('relation_tuple')
    
    
    for rel_t in rel_tuple:
        rel_t=rel_t.tolist()
        write_line=f'{ind_to_classes[gt_classes[sample_id][rel_t[0]]]}-{ind_to_predicates[rel_t[2]]}-{ind_to_classes[gt_classes[sample_id][rel_t[1]]]}'
        with open(f'{sample_id}/relation.txt','a') as rel_txt:
            rel_txt.write(write_line)
            rel_txt.write("\n")

# %%
import copy
sample_ids=[360,432,535]
for sample_id in sample_ids:
    img=cv2.imread(filenames[sample_id])
    target=get_groundtruth(sample_id)
    rel_tuple=target.get_field('relation_tuple')
    
    for rel_t in rel_tuple:
        rel_t=rel_t.tolist()
        head_box,head_cls=gt_boxes[sample_id][rel_t[0]],ind_to_classes[gt_classes[sample_id][rel_t[0]]]
        tail_box,tail_cls=gt_boxes[sample_id][rel_t[1]],ind_to_classes[gt_classes[sample_id][rel_t[1]]]
        predicate=ind_to_predicates[rel_t[2]]
        
        new_img=copy.deepcopy(img)
        cv2.rectangle(new_img,(int(head_box[0]),int(head_box[1])),(int(head_box[2]),int(head_box[3])),(random.randint(0,255),random.randint(0,255),random.randint(0,255)),1)
        cv2.rectangle(new_img,(int(tail_box[0]),int(tail_box[1])),(int(tail_box[2]),int(tail_box[3])),(random.randint(0,255),random.randint(0,255),random.randint(0,255)),1)
                
        head_box,tail_box=torch.from_numpy(head_box),torch.from_numpy(tail_box)
        union_box=torch.cat((torch.min(head_box[:2],tail_box[:2]),torch.max(head_box[2:],tail_box[2:])),dim=-1)
        
        rel_tri_img=new_img[int(union_box[1]):int(union_box[3]),int(union_box[0]):int(union_box[2]),...]
        cv2.imwrite(f'{sample_id}/{head_cls}-{predicate}-{tail_cls}.png',rel_tri_img)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
